# %%
def largestRectangle(arr,n):
    
    maxArea = -1
    
    for i in range(0,n):
        
        ht = arr[i]
        lt = 1  
        
        for j in range(i-1,-1,-1):
            if arr[i] < arr[j]:
                break
            else:
                lt += 1
        
        for j in range(i+1,n):
            if arr[i] < arr[j]:
                break
            else:
                lt += 1
        
        maxArea = max(maxArea,ht*lt)

# %%
def largestRectangle(arr,n):
    
    #currArea = (rightSmall[i] - leftSmall[i] + 1) * arr[i]
    
    # loop for finding the left smaller index and declaring a boundary there
    
    st = Stack()
    leftSmall = [-1]*n
    
    for i in range(0,n):

        if st.size == 0:
            leftSmall[i] = i
            st.push(i)
        else:
            while arr[st.top()] < arr[i]:
                st.pop()
            st.push(i)
            leftSmall[i] = st.top()

# %%
def nextSmallest(arr,n):
    
    # store the index for the next smallest element
    
    
    retList = [-1]*n
    
    st = Stack()
    
    for i in range(n-1,-1,-1):
        
        if st.isempty():
            retList[i] = n - 1
            st.push(i)
        else:
            while (not st.isempty()) and arr[st.top()] > arr[i]:
                st.pop()
                
            if st.isempty():
                st.push(i)
                retList[i] = n - 1
            else:
                retList[i] = st.top()
                st.push(i)
    
    return retList

# %%
def prevSmallest(arr,n):
    
    retList = []
    
    st = Stack()
    
    for i in range(n):
        
        if st.isempty():
            retList[i] = 0
            st.push(i)
        else:
            while (not st.isempty()) and arr[st.top()] > arr[i]:
                st.pop()
            
            if st.isempty():
                retList.append(0)
            else:
                retList.append(st.top())
            st.push(i)
    return retList
